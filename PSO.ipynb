# %%
import numpy as np

# %% [markdown]
# Take 100 particles , which are 14D vectors

# %%
np_parc = np.array(np.random.randint(2,size=14))
for i in range(99):
    to_app = np.random.randint(2,size=14)
    np_parc = np.append(np_parc,to_app)
np_parc=np_parc.reshape(100,14)

# %% [markdown]
# Generation of particles, here I'm taking only 50 generations and <br>
# Initialising Velocity, P_best and Fitness_Value for each particle to 0

# %%
def init_params():
    n_gen = 50
    n_vel = np.zeros([100,2])
    p_best = np.zeros([100,2])
    f_val = np.zeros(100)
    pos_x = np.random.uniform(low=-1000,high=1000,size=(100,2))
    g_best = np.array([0,0])
    U1,U2 = np.random.rand(),np.random.rand()
# Out:
#   File "<ipython-input-3-6aa618c0375e>", line 1
#     def update_params(n_vel,)
#                              ^
# SyntaxError: invalid syntax

# %%
p_best_g=p_best
p_best_g[:,1] = g_best[0]
p_best_g = p_best_g.reshape(100,2)
p_best = p_best.reshape(100,2)
p_best_g.shape
n_vel = n_vel + 2*((U1 * (p_best - pos_x)+ U2*(p_best_g - pos_x)))

# %%
n_vel
# Out:
# array([[-2769.04408683, -3340.15769309],
#        [-2425.22088919,  2100.59016892],
#        [-1890.7961995 ,  1225.21633218],
#        [  688.82243609,  3352.74907179],
#        [-3075.50857963, -2182.00421628],
#        [ -743.17546728,  2715.65636642],
#        [-2432.52741392, -1653.57167266],
#        [  320.15616307, -2597.06877529],
#        [-2374.26782421, -3009.76444952],
#        [-2759.51274179, -1521.12381452],
#        [-2806.51962686,  -423.5973258 ],
#        [-1519.47871476,  1344.07594561],
#        [-1612.45770026,  -923.81435673],
#        [ 2662.2947805 ,   -32.79364627],
#        [-1468.20928944,  1292.23298762],
#        [ -788.63966562,  2881.25259628],
#        [-1563.38656398,  1130.67137595],
#        [-2420.2174015 ,  -118.71368375],
#        [-1793.65021753,  1340.06527851],
#        [  967.03665646,  2233.69006173],
#        [ 1715.57950088, -2774.72735674],
#        [ 2710.54177727,  -472.09385544],
#        [ -511.27480528,  1299.616558  ],
# ...
