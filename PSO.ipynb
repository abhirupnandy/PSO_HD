# %%
import numpy as np

# %% [markdown]
# Take 100 particles , which are 14D vectors

# %%
np_parc = np.array(np.random.randint(2,size=14))
for i in range(99):
    to_app = np.random.randint(2,size=14)
    np_parc = np.append(np_parc,to_app)
np_parc=np_parc.reshape(100,14)

# %% [markdown]
# Generation of particles, here I'm taking only 50 generations and <br>
# Initialising Velocity, P_best and Fitness_Value for each particle to 0

# %%
def update_params(n_vel,)

# %%
n_gen = 50
n_vel = np.zeros([100,2])
p_best = np.zeros([100,2])
f_val = np.zeros(100)
pos_x = np.random.uniform(low=-1000,high=1000,size=(100,2))
g_best = np.array([0,0])
U1,U2 = np.random.rand(),np.random.rand()

# %%
p_best_g=p_best
p_best_g[:,1] = g_best[0]
p_best_g = p_best_g.reshape(100,2)
p_best = p_best.reshape(100,2)
p_best_g.shape
n_vel = n_vel + 2*((U1 * (p_best - pos_x)+ U2*(p_best_g - pos_x)))

# %%
n_vel
# Out:
# array([[-1273.72385958,  1045.54273298],
#        [  934.95618599,    88.75573724],
#        [ -849.32190901,   154.01712952],
#        [  467.34410502,  -821.2322373 ],
#        [ -537.59921224,  -281.73381336],
#        [ -846.97503576, -1203.06663382],
#        [   44.57772546, -1079.98794762],
#        [  969.33769612, -1453.75326239],
#        [-1090.07085059,  1222.88346332],
#        [ 1462.2989483 ,  -411.19227078],
#        [ -460.16976014,  1738.13783133],
#        [-1102.35186285,  -982.76739269],
#        [  209.79932316,  -842.43496955],
#        [ 1786.08144729,  1567.1295554 ],
#        [-1678.52188617,  1515.31153892],
#        [-1184.09007719,  1645.42536605],
#        [ -595.09058851,  1794.89313351],
#        [ -727.73989914, -1830.46962337],
#        [  892.85759768, -1565.70040094],
#        [ 1619.15838886,   852.23866233],
#        [ 1579.31014024,  -814.76871276],
#        [-1054.93098658,  -437.23362161],
#        [-1577.96898071, -1089.84925236],
#        [  731.16223789,  -999.19029989],
#        [ -701.99331489,  1545.69768986],
#        [ -391.60812838,  1403.85083633],
#        [ 1915.86110705,   472.53310498],
#        [-1402.04105599,  1266.52506041],
#        [ -388.93524942,  1211.74684659],
#        [  -57.94475692, -1646.43926546],
#        [  806.84928585,  -708.17867952],
#        [ 1234.43058711,  -403.84060922],
#        [  115.47199011, -1505.48836924],
#        [-1388.07339784,  -113.14492396],
#        [ 1251.05750206,  -709.2723045 ],
#        [-1183.91622482,  -215.15485738],
#        [-1538.68948625,  1194.73453987],
#        [ 1402.75232984,  -152.96735525],
#        [ -341.40917243, -1006.93601209],
#        [ 1903.15066848, -1504.14820838],
#        [-1721.44464537,  1670.62382804],
#        [ 1577.32339825, -1257.80804857],
#        [ -679.46019206,  1101.67153645],
#        [ 1169.31745268,   237.80218659],
#        [ 1245.0543908 ,  1387.30637073],
#        [-1294.36038086,  1812.9001834 ],
#        [  597.4513205 ,  -156.41652197],
#        [ 1253.99625394,  1322.14815436],
#        [  212.17240198,  1021.67961045],
#        [  182.78563107, -1432.3824565 ],
#        [-1173.47560896,  -351.09856238],
#        [ -800.51240817,  -857.73340688],
#        [  807.2280461 ,  -892.95376431],
#        [ 1846.7050876 ,   537.97061306],
#        [ -308.41675218,  1908.10048016],
#        [ 1048.59040115,   -64.96434425],
#        [ 1408.84561855,  1240.67000072],
#        [  218.82194745,  -243.04869003],
#        [ -857.50521031,  -931.37861767],
#        [ -581.87424624,    25.81708669],
#        [ -349.96021301,   153.36395996],
#        [ 1507.2608453 ,   381.74131239],
#        [ -988.52813139,  -599.81183538],
#        [-1055.0899383 , -1927.28635624],
#        [-1567.48695407,  -868.33791405],
#        [-1909.4634262 ,  -399.68779322],
#        [ 1852.17465395,  -217.73388818],
#        [  299.22884299,  -322.22456754],
#        [  497.77374571,  -867.11125672],
#        [-1447.69219011,  1147.9134227 ],
#        [ -395.05451287,   267.70593885],
#        [ 1705.26034562,   982.82414628],
#        [ 1638.89397668,   870.81775898],
#        [-1000.29422319, -1787.19658668],
#        [  922.06562826,   428.61344034],
#        [-1034.58479421, -1869.17208949],
#        [ 1880.29731028,  -633.16188843],
#        [  744.04392702, -1570.40766825],
#        [ -747.77373086,    75.61179867],
#        [-1697.51388404,  -109.12124759],
#        [ -871.79893016, -1825.3160719 ],
#        [ 1745.83491385,  1008.6979559 ],
#        [-1866.84405847, -1702.62398946],
#        [ 1210.10457815, -1560.42435703],
#        [  584.30029153,  1871.48365569],
#        [  770.00817144,   788.14094934],
#        [  -42.36021472,  1169.83266811],
#        [-1034.55481104, -1231.49011629],
#        [ 1813.84434217,   412.95814806],
#        [-1330.77675888,  -318.19259774],
#        [ 1370.66818231,  1936.69386918],
#        [ 1028.45446716,  -942.86795094],
#        [-1695.19071346,   815.94359926],
#        [  -27.22314003,  -764.74842762],
#        [ 1370.92730195,  1081.05542481],
#        [ -968.58725592,  -713.95893431],
#        [ -484.33768089, -1804.981452  ],
#        [  514.23936799,   129.23761145],
#        [ -219.98870743,   411.26428267],
#        [  983.28308294, -1276.53383582]])
